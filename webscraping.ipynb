# %%
import pandas as pd
from httpx import get
import numpy as np
from selectolax.parser import HTMLParser
import spacy
from nltk.corpus import stopwords
import string
from textblob import TextBlob
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import re

# %% [markdown]
# # News Scraper

# %%
url = "https://www.medicalnewstoday.com/news"

# %%
resp = get(url)

tree = HTMLParser(resp.text)

headlines = [h.text() for h in tree.css("h2")]
summaries = [s.text() for s in tree.css("p a")]
dates = [d.text() for d in tree.css("figure + div > div")]
links = [l.attributes['href'] for l in tree.css("p a")]

# %%
print(f"Headlines: {len(headlines)}")
print(f"Summaries: {len(summaries)}")
print(f"Dates: {len(dates)}")
print(f"Links: {len(links)}")
# Out:
# Headlines: 40
# Summaries: 40
# Dates: 40
# Links: 40

# %%
df = pd.DataFrame(
        {
            "Headline": headlines,
            "Summary": summaries,
            "Date": dates,
            "Link": links
        }
    )

df['Date'] = pd.to_datetime(df['Date'])
df.shape
# Out:
# (40, 4)

# %%
nlp = spacy.load("en_core_web_sm")

def preprocess(text):

    stop_words = set(stopwords.words("english"))
    punctuations = string.punctuation

    doc = nlp(text)
    tokens = [token.lemma_.lower() for token in doc if token.text.lower() not in stop_words and token.text not in punctuations]

    return " ".join(tokens)

# %%
df['Preprocessed_Summary'] = df['Summary'].apply(preprocess)

df.head()
# Out:
#                                             Headline  \
# 0  Alcohol use could contribute to dementia by da...
# 1  Can weight training protect your brain from de...
# 2  Diabetes drugs like Ozempic or Jardiance may s...
# 3  Certain combos of common food additives may ra...
# 4  Expert Q&A: Should you get a measles vaccine b...
#
#                                              Summary       Date  \
# 0  Heavy and former heavy drinking is associated ... 2025-04-14
# 1  Weight training may help protect the brains of... 2025-04-10
# 2  Two common types of anti-diabetes medications ... 2025-04-09
# 3  Two certain mixtures of common food additives,... 2025-04-09
# 4  A board-certified family medicine physician ex... 2025-04-08
#
#                                                 Link  \
# 0  https://www.medicalnewstoday.com/articles/alco...
# 1  https://www.medicalnewstoday.com/articles/can-...
# 2  https://www.medicalnewstoday.com/articles/diab...
# 3  https://www.medicalnewstoday.com/articles/cert...
# 4  https://www.medicalnewstoday.com/articles/expe...
#
#                                 Preprocessed_Summary
# 0  heavy former heavy drinking associate brain ab...
# 1  weight training may help protect brain old adu...
# 2  two common type anti diabetes medication — glp...
# 3  two certain mixture common food additive inclu...
# 4  board certify family medicine physician explai...

# %%
def get_sentiment(text):
    blob = TextBlob(text)
    return blob.sentiment.polarity

# %%
df['Sentiment'] = df['Preprocessed_Summary'].apply(get_sentiment)
df['Sentiment_Label'] = df['Sentiment'].apply(lambda x: "Positive" if x>0 else "Negative" if x < 0 else "Neutral")

df.head()
# Out:
#                                             Headline  \
# 0  Alcohol use could contribute to dementia by da...
# 1  Can weight training protect your brain from de...
# 2  Diabetes drugs like Ozempic or Jardiance may s...
# 3  Certain combos of common food additives may ra...
# 4  Expert Q&A: Should you get a measles vaccine b...
#
#                                              Summary       Date  \
# 0  Heavy and former heavy drinking is associated ... 2025-04-14
# 1  Weight training may help protect the brains of... 2025-04-10
# 2  Two common types of anti-diabetes medications ... 2025-04-09
# 3  Two certain mixtures of common food additives,... 2025-04-09
# 4  A board-certified family medicine physician ex... 2025-04-08
#
#                                                 Link  \
# 0  https://www.medicalnewstoday.com/articles/alco...
# 1  https://www.medicalnewstoday.com/articles/can-...
# 2  https://www.medicalnewstoday.com/articles/diab...
# 3  https://www.medicalnewstoday.com/articles/cert...
# 4  https://www.medicalnewstoday.com/articles/expe...
#
#                                 Preprocessed_Summary  Sentiment  \
# 0  heavy former heavy drinking associate brain ab...  -0.133333
# 1  weight training may help protect brain old adu...   0.167424
# 2  two common type anti diabetes medication — glp...   0.096429
# 3  two certain mixture common food additive inclu...   0.138095
# 4  board certify family medicine physician explai...   0.100000
#
#   Sentiment_Label
# 0        Negative
# 1        Positive
# 2        Positive
# 3        Positive
# 4        Positive

# %%
tfidf = TfidfVectorizer(max_df=0.85, max_features=50)

tfidf_matrix = tfidf.fit_transform(df['Preprocessed_Summary'])
feature_names = tfidf.get_feature_names_out()

# %%
def get_top_keywords(tfidf_matrix, feature_names, n):
    top_keywords = []
    
    for doc in tfidf_matrix:
        top_indices = doc.toarray().argsort()[0][-n:][::-1]
        top_keywords.append([feature_names[i] for i in top_indices])

# %%
def extract_entities(text):
    doc = nlp(text)
    entities = [(ent.text, ent.label_) for ent in doc.ents]
    
    return entities

# %%
df['Top_Keywords'] = get_top_keywords(tfidf_matrix, feature_names, 6)
df['Entities']= df['Preprocessed_Summary'].apply(extract_entities)

df.head()
# Out:
#                                             Headline  \
# 0  Alcohol use could contribute to dementia by da...
# 1  Can weight training protect your brain from de...
# 2  Diabetes drugs like Ozempic or Jardiance may s...
# 3  Certain combos of common food additives may ra...
# 4  Expert Q&A: Should you get a measles vaccine b...
#
#                                              Summary       Date  \
# 0  Heavy and former heavy drinking is associated ... 2025-04-14
# 1  Weight training may help protect the brains of... 2025-04-10
# 2  Two common types of anti-diabetes medications ... 2025-04-09
# 3  Two certain mixtures of common food additives,... 2025-04-09
# 4  A board-certified family medicine physician ex... 2025-04-08
#
#                                                 Link  \
# 0  https://www.medicalnewstoday.com/articles/alco...
# 1  https://www.medicalnewstoday.com/articles/can-...
# 2  https://www.medicalnewstoday.com/articles/diab...
# 3  https://www.medicalnewstoday.com/articles/cert...
# 4  https://www.medicalnewstoday.com/articles/expe...
#
#                                 Preprocessed_Summary  Sentiment  \
# 0  heavy former heavy drinking associate brain ab...  -0.133333
# 1  weight training may help protect brain old adu...   0.167424
# 2  two common type anti diabetes medication — glp...   0.096429
# 3  two certain mixture common food additive inclu...   0.138095
# 4  board certify family medicine physician explai...   0.100000
#
#   Sentiment_Label Top_Keywords                            Entities
# 0        Negative         None                                  []
# 1        Positive         None                                  []
# 2        Positive         None  [(two, CARDINAL), (sglt2, PERSON)]
# 3        Positive         None                   [(two, CARDINAL)]
# 4        Positive         None                                  []

# %%
text = " ".join(df["Summary"].dropna())

wc = WordCloud(width=1200, height=500, background_color="rgba(255, 255, 255, 0)", mode="RGBA").generate(text)

plt.figure(figsize=(10,5))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

wc.to_file("wordcloud.png")

# %%
sns.histplot(df["Sentiment"], bins=20, kde=True)
plt.title("Sentiment Distribution of Medical News")
plt.show()

# %% [markdown]
# ### As the website structure of 'healthline' is similar to 'medicalnewstoday', I decided to loop through the process as I have wrapped the whole script and defined a function.

# %% [markdown]
# # PubMed Research Articles

# %%
url = "https://pubmed.ncbi.nlm.nih.gov/trending/?sort=date"

# %%
resp = get(url)
resp.status_code
# Out:
# 200

# %%
tree = HTMLParser(resp.text)
tree
# Out:
# <HTMLParser chars=270100>

# %%
ids = [id.attrs['data-article-id'] for id in tree.css("article .docsum-title")]
headings = [id.text().strip() for id in tree.css("article .docsum-title")]
links = [f"https://pubmed.ncbi.nlm.nih.gov{l.attrs['href']}" for l in tree.css("article .docsum-title")]
authors = [a.text().split(", ") for a in tree.css("article .full-authors")]
tags = [" ".join(t.text().split()[:-1]) for t in tree.css(".short-journal-citation")]
years = [int("".join(t.text().split()[-1].replace(".",""))) for t in tree.css(".short-journal-citation")]

# %%
df = pd.DataFrame(
        {
            "ID": ids,
            "Article": headings,
            "Authors": authors,
            "Published_Year":years,
            "Tag": tags,
            "Link": links
        }
    )

df.shape
# Out:
# (10, 6)

# %% [markdown]
# # COVID-19 Summary

# %%
url = "https://covid-19.dataflowkit.com/v1"

# %%
resp = get(url)
resp.status_code
# Out:
# 200

# %%
# The above url is an api, so it's response will not be in a HTML ot XML format, rather it will be in a JSON format.
# It is quite easy to make a dataframe as pandas is easily read the json

df = pd.DataFrame(resp.json())
df.head()
# Out:
#   Active Cases_text Country_text       Last Update New Cases_text  \
# 0                          World  2025-04-25 05:49      7,010,681
# 1       334,805,269          USA  2025-04-25 05:49      1,219,487
# 2     1,406,631,776        India  2025-04-25 05:49        533,570
# 3        65,584,518       France  2025-04-25 00:49        167,642
# 4        83,883,596      Germany  2025-04-25 04:49        183,027
#
#   New Deaths_text Total Cases_text Total Deaths_text Total Recovered_text
# 0          90,413      704,753,890       675,619,811                899.4
# 1         333,985      111,820,082       109,814,428                3,642
# 2          32,016       45,035,393               N/A                  379
# 3         612,013       40,138,560        39,970,918                2,556
# 4         462,891       38,828,995        38,240,600                2,182

# %%
# Cleaning process
num_cols = ['Active Cases_text', 'New Cases_text', 'New Deaths_text', 'Total Cases_text', 'Total Deaths_text', 'Total Recovered_text']

for col in num_cols:
    df[col]=pd.to_numeric(df[col].map(lambda x: x.strip().replace(",","") if isinstance(x, str) else x), errors='coerce')

df.loc[0, 'Active Cases_text'] = df['Active Cases_text'].sum()

df.head()
# Out:
#    Active Cases_text Country_text       Last Update  New Cases_text  \
# 0       7.944935e+09        World  2025-04-25 05:49       7010681.0
# 1       3.348053e+08          USA  2025-04-25 05:49       1219487.0
# 2       1.406632e+09        India  2025-04-25 05:49        533570.0
# 3       6.558452e+07       France  2025-04-25 00:49        167642.0
# 4       8.388360e+07      Germany  2025-04-25 04:49        183027.0
#
#    New Deaths_text  Total Cases_text  Total Deaths_text  Total Recovered_text
# 0          90413.0       704753890.0        675619811.0                 899.4
# 1         333985.0       111820082.0        109814428.0                3642.0
# 2          32016.0        45035393.0                NaN                 379.0
# 3         612013.0        40138560.0         39970918.0                2556.0
# 4         462891.0        38828995.0         38240600.0                2182.0

# %%
df['Last Update'] = pd.to_datetime(df['Last Update'], errors='coerce')

df.head()
# Out:
#    Active Cases_text Country_text         Last Update  New Cases_text  \
# 0       7.944935e+09        World 2025-04-25 05:49:00       7010681.0
# 1       3.348053e+08          USA 2025-04-25 05:49:00       1219487.0
# 2       1.406632e+09        India 2025-04-25 05:49:00        533570.0
# 3       6.558452e+07       France 2025-04-25 00:49:00        167642.0
# 4       8.388360e+07      Germany 2025-04-25 04:49:00        183027.0
#
#    New Deaths_text  Total Cases_text  Total Deaths_text  Total Recovered_text
# 0          90413.0       704753890.0        675619811.0                 899.4
# 1         333985.0       111820082.0        109814428.0                3642.0
# 2          32016.0        45035393.0                NaN                 379.0
# 3         612013.0        40138560.0         39970918.0                2556.0
# 4         462891.0        38828995.0         38240600.0                2182.0

# %%
df.columns = ["_".join(i.split()) for i in df.columns.str.replace("_text","")]

df.head()
# Out:
#    Active_Cases  Country         Last_Update  New_Cases  New_Deaths  \
# 0  7.944935e+09    World 2025-04-25 05:49:00  7010681.0     90413.0
# 1  3.348053e+08      USA 2025-04-25 05:49:00  1219487.0    333985.0
# 2  1.406632e+09    India 2025-04-25 05:49:00   533570.0     32016.0
# 3  6.558452e+07   France 2025-04-25 00:49:00   167642.0    612013.0
# 4  8.388360e+07  Germany 2025-04-25 04:49:00   183027.0    462891.0
#
#    Total_Cases  Total_Deaths  Total_Recovered
# 0  704753890.0   675619811.0            899.4
# 1  111820082.0   109814428.0           3642.0
# 2   45035393.0           NaN            379.0
# 3   40138560.0    39970918.0           2556.0
# 4   38828995.0    38240600.0           2182.0
